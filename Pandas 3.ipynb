# %% [markdown]
# ## Reading, writing CSV and Excel file

# %%
import pandas as pd

# %%
#Reading CSV file
d=pd.read_csv('Iris.csv')
d.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
#Reading excel file
df=pd.read_excel('Retail.xlsx')
df.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %% [markdown]
# ### If you want to read only few rows rather than all

# %%
df=pd.read_csv('Iris.csv',nrows=7)
df
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa

# %% [markdown]
# ### Changing specific values with NaN while reading

# %% [markdown]
# #### While reading the dataset you can change the specific value with NaN
# `df = pd.read_excel ( "Retail.xlsx " , na_values = [ list of element which you want to change to NaN ] )`

# %%
df = pd.read_excel("Retail.xlsx",na_values=[None]) 
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Changing specific values with NaN columns wise while reading

# %%
#na_values={'col_name':[Value_you_want]}
df=pd.read_excel('Retail.xlsx',na_values={'StockCode':[None],'Description':[None],'Quantity':[2,0]})
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# `na_values` argument is used to replace all the values passes in the list with NaN.You can also replace some invalid values column wise as you can in the above code. If you run the above code you will a dataframe where 'None' in body column is replaced by NaN,again None in the boat column is replaced by NaN and 2 & 0 in parch column are replaced by NaN.

# %% [markdown]
# ## how many columns in dataframe df ?

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# # Converters :
# In various cases you dont have clean dataset. Invalid values in the dataset leads to a lot of problem while predicting or extracting the meaningful information.To avoid this problem we use converters.

# %% [markdown]
#     1. Converters are basically functions which convert the specific value of a column in your desire value
#     2. Converter function passed into the disctionary like in the na_values.

# %%
p=pd.read_csv('season.csv')

# %%
p
# Out:
#         dates    day  temp     wind_speed
# 0  02-01-2012  sunny  45.0             12
# 1  03-01-2012  rainy  46.0             34
# 2  04-01-2012    hot  47.0             45
# 3  05-01-2012    NaN   NaN             56
# 4  06-01-2012    hot  49.0  Not available
# 5  07-01-2012    NaN   NaN  Not available
# 6  08-01-2012    hot  12.0             45
# 7  09-01-2012  rainy  23.0             41
# 8  10-01-2012    NaN   NaN            NaN
# 9  11-01-2012    NaN   NaN            NaN

# %% [markdown]
# Converters are basically functions which convert the specific value of a column in your desire value
# Converter function passed into the disctionary like in the na_values.

# %%
def converter_for_temp(col):
    if col=='NaN':
        return 40
    else:
        return col
def converter_for_day(col):
    if col=='NaN':
        return 'sunny'
    else:
        return col
def converter_for_wind_speed(col):
    if col=='Not available':
        return 30
    elif col=="NaN":
        return 48
    else:
        return col

# %%
p=pd.read_csv('season.csv',converters={
    'day':converter_for_day,
    'temp':converter_for_temp,
    'wind-speed':converter_for_wind_speed
   })
p
# Out:
#         dates    day temp     wind_speed
# 0  02-01-2012  sunny   45             12
# 1  03-01-2012  rainy   46             34
# 2  04-01-2012    hot   47             45
# 3  05-01-2012  sunny   40             56
# 4  06-01-2012    hot   49  Not available
# 5  07-01-2012  sunny   40  Not available
# 6  08-01-2012    hot   12             45
# 7  09-01-2012  rainy   23             41
# 8  10-01-2012  sunny   40            NaN
# 9  11-01-2012  sunny   40            NaN

# %% [markdown]
# You can observe that previously the columns 'day', 'temp' and 'wind-speed' had some invalid data like 'NaN','NAN','Not available' but after applying the converter functions we got a cleaned dataset.Now we can apply some data analysis techniquw to predict something in our dataset.
